# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Hello my name is MInh

# %%
# !git add .

# Bước 2: Đóng gói sự thay đổi đó kèm theo một lời nhắn
# !git commit -m "Update PhoBert"

# Bước 3: Đẩy bản cập nhật lên GitHub
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# Hllo everyone, You're like shi
